# %% [markdown]
# ## Setup instructions
#
# Website @ ISCA'26: https://tutorial.xiangshan.cc/isca26/hands_on/setup/
#
# 1. Open https://t.xiangshan.cc in your browser
# 2. Enter password: **ISCA26**
# 3. By default you should see a terminal
#    - If not, click Menu (triple dashes) on the top-left corner, then "Terminal > New Terminal"
# 4. Run `./start.sh` in the terminal
# 5. This will create a unique random id for you, and create your workspace at `/data/${random_id}`
# 6. When your workspace is created, it should be opened automatically
#    - If not, click "Menu > File > Open Folder", enter `/data/${random_id}`, then click "OK"
# 7. For a quick start, open the Jupyter notebooks (.ipynb) under `01-basic` to `04-gem5` and follow slides step by step.
# 7. Feel free to ask the instructors for help any time if you have any problem

# %% [markdown]
# Let's begin with setup instructions. First, open https://t.xiangshan.cc in your brower, and enter the password ISCA26. Then you will see a terminal, run the start script here. It will create a workspace under a unique id. If the workspace does not open automatically or if you have any questions during the hands on, please raise your hand and the instructors will come to help you.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ## Welcome to XiangShan Tutorial
#
# Hands-on notebooks are in `01-basics`, `02-functional`, `03-performance` and `04-gem5`. Please open the corresponding `.ipynb` file for each section.

# %% [markdown]
# ### OK, welcome to the XiangShan tutorial. The hands-on materials are organized as Jupyter notebooks in your directories, from 01-basics to 04-gem5. Please open the corresponding file when we reach each section. The jupyter notebooks will help you run command with a simple click.
#
# ----- Speaker notes divider -----

# %% [markdown]
# A Jupyter Notebook consists of multiple cells, each of which can contain python/bash code or text. We use text cells to write these instructions you are reading, and code cells to place the code you can run.
#
# - Cells that start with %%bash are Bash scripts; the rest are Python code.
# - Lines that start with # are comments.

# %% [markdown]
# You can click ▶ in the top-left corner of a code cell to run that single cell; the output will be displayed below the cell.
#
# When you open a Notebook for the first time, you may encounter the problem that the environment is not detected correctly. If a pop-up window appears at the top of the page prompting "Select Kernel" when you click run, please select "Python Environments" > "Python 3.x.y /bin/python3 (Global Env)".
#
# <div style="text-align: center;"><img src="../images/01-basics/00-welcome/select-kernel-1.png" width="25%"> > <img src="../images/01-basics/00-welcome/select-kernel-2.png" width="25%"></div>

# %% [markdown]
# Let's do a quick notebook warm-up. The next two cells show the two styles we will use today: Bash cells for shell commands, and normal Python cells for Python code. (RUN) Please run both cells by click the run button in the top-left corner. If Jupyter asks for a kernel, choose Python option in your screens.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# echo "[bash] Welcome to the XiangShan Bootcamp!"

# %%
print("[python] Welcome to the XiangShan Bootcamp!")

# %% [markdown]
# Each cell has its own working directory and environment variables, so some commands may need to be rerun. If you execute these commands directly in the shell, you can skip the repetitive parts, e.g. `source env.sh`.

# %% [markdown]
# And one more notebook detail. Each cell starts with a fresh shell, with its own directory and envrionments. So a cd or export does not carry into the next cell. That is why many cells repeat source ../env.sh or cd into a directory.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# # For example, in this cell, we change the working directory,
# pwd
# cd ..
# pwd
# # ... and set some environment variables,
# export HELLO_WORLD="XiangShan Bootcamp!"
# echo Hello $HELLO_WORLD

# %%
# %%bash
# # ... we can see that the changes made in the previous cell do not take effect in this cell.
# pwd
# echo Hello $HELLO_WORLD

# %% [markdown]
# ### About the `get_asset` funtion
#
# You may see the use of the `get_asset` function in the following chapters.
#
# ```bash
# # For example, using the pre-compiled simulation program emu
# $(get_asset emu-precompile/emu)
# # This will return the absolute path of assets/emu-precompile/emu
#
# # Or, prefer to use locally compiled files (if they exist)
# $(get_asset emu-precompile/emu ${NOOP_HOME}/build/emu)
# # If you have done local compilation, ${NOOP_HOME}/build/emu will exist and be returned preferentially. Otherwise, it falls back to assets/emu-precompile/emu
# ```

# %% [markdown]
# As compiling XiangShan and related tools may take a long time and computing resources. In the hands-on, we will use get_asset function. It will help us use precompiled files, so everyone can run the examples quickly and keep up with the flow.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ## Configure and Build
#
# In this section, we present the workflow for configuring and building XiangShan.

# %% [markdown]
# Now let's move to the XiangShan build flow. The build path has three parts: choose a configuration, generate RTL from Chisel, and compile an emu simulator with Verilator.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ### Configure
#
# Benefiting from the flexibility provided by Chisel, an OOP HDL, XiangShan offers a wide range of configurable parameters for researchers and industry customization.
#
# ```scala
# // xiangshan/frontend/FrontendParameters.scala
# case class FrontendParameters(
#     FetchBlockSize:   Int              = 64, // bytes
#     bpuParameters:    BpuParameters    = BpuParameters(),
#     icacheParameters: ICacheParameters = ICacheParameters(),
#     // ...
# ) { ... }
#
# // xiangshan/frontend/icache/Parameters.scala
# case class ICacheParameters(
#     NumSets:   Int     = 256,
#     NumWays:   Int     = 4,
#     Replacer:  String  = "setplru", // "random", "setlru", "setplru"
#     EnableEcc: Boolean = true,      // whether to enable ECC or parity check
#     // ...
# ) { ... }
# ```

# %% [markdown]
# Benefiting from Chisel, XiangShan provides a wide range of configurable parameters. For example, FrontendParameters contains BPU and Icache choices, and ICacheParameters contains further detaileds choice, such as NumSets, NumWays, replacement policy, and ECC. So researchers can easily replace an existing policy or test a new idea on XiangShan with mirror changes.
#
# ----- Speaker notes divider -----

# %% [markdown]
# Subsequently, for researchers and industry users, these parameter classes can be instantiated in `top/Configs.scala` to quickly generate different configurations:
#
# ```scala
# // Default configuration
# class DefaultConfig extends Config(
#     // ...
#     frontendParameters = FrontendParameters()
#     // ...
# )
#
# // Minimal configuration for quick functional verification, with smaller resources to speed up compilation and simulation
# class MinimalConfig extends Config(
#     // ...
#     frontendParameters = FrontendParameters(
#       FetchBlockSize = 32,
#       icacheParameters = ICacheParameters(
#         NumSets = 64,
#       )
#     )
#     // ...
# )
# ```

# %% [markdown]
# The parameteres can be put into a configuration classes. For example, DefaultConfig keeps the default parameters. MinimalConfig changes some fields to produce a smaller design. In the same way, a researcher can create a new config for an experimental cache, predictor, or policy, and then select it with make options for evaluation on XiangShan.
#
# ----- Speaker notes divider -----

# %% [markdown]
# Finally, different configurations can be compiled at build time using `make CONFIG=XXXConfig`.

# %% [markdown]
# ### Wait a minute!
#
# Due to some historical reasons, the build workflow of XiangShan depends on certain environment variables, such as `NOOP_HOME`. We provide an `env.sh` script to help you set up these environment variables.
#
# You can run the following cell to view these environment variables:

# %% [markdown]
# As the build workflow of XiangShan depends on certain environment variables. We provide an env.sh script to help you set up these environment variables. Please run the following cells to check it.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
#
# env | grep _HOME | outputBuffer

# %% [markdown]
# ### Build
#
# After the environment setup, go to `$NOOP_HOME` to build XiangShan.

# %% [markdown]
# With the environment ready, the build happens inside $NOOP_HOME. The cell shows the real make command and other options.
# As the emu compilation take about tens of minutes. Let's skip the compilation and move to next part.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# #make emu -j16 CONFIG=MinimalConfig
#
# # Additional make options
# # CONFIG=MinimalConfig  XiangShan configuration
# # EMU_THREADS=4         Simulation thread count
# # EMU_TRACE=1           Enable waveforms
# # WITH_DRAMSIM=1        Simulate DRAM with DRAMSim3
# # WITH_CHISELDB=1       Enable ChiselDB
# # WITH_CONSTANTIN=1     Enable Constantin

# %% [markdown]
# The commands above will generate outputs like `build/emu` and `build/rtl`.
#
# - build/rtl/*.sv is Verilog files generated by Chisel.
# - build/emu is a simulation executable further compiled with Verilator.

# %% [markdown]
# After a successful build, there are two outputs to remember. build/rtl contains generated Verilog files. build/emu is the simulator executable. In the rest of the tutorial, when we say we run emu, this is the executable we mean.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ## Build the workload using Nexus-AM

# %% [markdown]
# A simulator is not useful until it has a program to execute. Nexus-AM gives us the small bare-metal runtime and build system needed for XiangShan workloads. In other words, this section turns a C program into an image that XiangShan's emu can load.
#
# ----- Speaker notes divider -----

# %% [markdown]
# In the previous section, we built the XiangShan emulator `emu`. However, we cannot directly run an arbitrary ELF file on it. This is because XiangShan is a bare-metal device that does not provide support such as operating systems or runtime libraries.
#
# Linux? Too heavyweight.
#
# Nexus-AM: a lightweight framework for bare-metal machines.

# %% [markdown]
# The `am/` directory contains the Nexus-AM framework sources; `apps/` and `tests/` hold common workload sources, and you can create your own apps and tests.

# %% [markdown]
# Let's inspect the Nexus-AM directory layout. (RUN) Run the next cell and look at am, apps, and tests. The framework lives under am, while ready-to-build workloads live under apps and tests. You can also add your own workloads in the same structure.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${AM_HOME}
#
# tree -d -L 1 | outputBuffer
#
# echo "- Apps: $(ls -m ./apps)"
# echo "- Tests: $(ls -m ./tests)"

# %% [markdown]
# We start with a simple "Hello, XiangShan" example, whose source code is located in the `${AM_HOME}/apps/hello` directory. We can compile it using `make`:

# %% [markdown]
# We start with the smallest workload, Hello XiangShan. The source is in ${AM_HOME}/apps/hello. (RUN) Run the make cell.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd $AM_HOME/apps/hello
#
# # compiling
# # ARCH=riscv64-xs for XiangShan
# # LINUX_GNU_TOOLCHAIN=1 to use the GNU toolchain from Ubuntu apt repo, instead of riscv64-unknown-elf
# make ARCH=riscv64-xs LINUX_GNU_TOOLCHAIN=1 | outputBuffer
#
# # check output
# ls build

# %% [markdown]
# This will generate the following three files:
#
# - hello-riscv64-xs.bin：Program binary image (The ELF header and other metadata was removed) for emu.
# - hello-riscv64-xs.elf：The program's ELF file.
# - hello-riscv64-xs.txt：The program’s disassembly for debugging

# %% [markdown]
# The build creates three useful files. The binary file is the raw image that emu loads. The ELF file keeps metadata for debugging. The .txt file is the disassembly, which helps us to check the instruction or program counters.
#
# ----- Speaker notes divider -----

# %% [markdown]
# Nexus-AM supports multiple ISAs and configurations. You can compile for different targets by passing different `ARCH` values. For example, `riscv64-xs` used above is for XiangShan's RISC-V 64-bit architecture.
#
# If the ARCH you pass isn’t supported, `make` will print all supported ARCH values.

# %% [markdown]
# Nexus-AM can target more than RISCV or XiangShan. Please run the cell, and see supported ARCH values. (RUN)
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${AM_HOME}
#
# # || true to prevent notebook erroring out on non-zero exit code
# make ARCH= || true

# %% [markdown]
# ## Run RTL simulation

# %% [markdown]
# Now we have a simulator and a workload, let's come to RTL simulation. (RUN) Execute the emu --help, and that's the options, including the input image option, DiffTest options, waveform controls, logs, and database options.
#
# ----- Speaker notes divider -----

# %% [markdown]
# XiangShan's emu supports many options, run emu --help to see usage.

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# $(get_asset emu-precompile/emu ${NOOP_HOME}/build/emu) --help | outputBuffer

# %% [markdown]
# Run Hello XiangShan:

# %% [markdown]
# Now let's run the Hello image on emu. (RUN) And you can see Hello XiangShan and Good Trap in your screen.
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# $(get_asset emu-precompile/emu ${NOOP_HOME}/build/emu) \
#     -i $(get_asset workload/hello-riscv64-xs.bin ${AM_HOME}/apps/hello/build/hello-riscv64-xs.bin) \
#     --no-diff\
#     2>/dev/null | outputBuffer

# %% [markdown]
# ![MinJie Cycle](../images/02-functional/00-intro/overal-en.png)

# %% [markdown]
# The happy path is useful, but processor development is mostly about finding wrong behavior. This MinJie diagram is the loop we will follow: run the design, detect a mismatch, collect targeted evidence, analyze the evidence, and iterate.
# For test generation, we use Nexus-AM. For bug detection, we porpose Difftest and NEMU.
# For preserving context for debugging, we prospose LightSSS. And also waveform and chiselDB for troubleshoot and fix bugs.
# The next examples walk through that loop with injected bugs.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ### Why we need Minjie
#
# We manually injected an bug into the ALU module and compiled emu for you to test:

# %% [markdown]
# So why we need Minjie, the order is to let the failure visible. We have prepared an emu with injected ALU bug. (RUN) Run the cell and compare it with the previous Hello run. You will find there is no HELLO XIANGSHAN after 20 thousand instruction. Something is wrong, but where is it?
# MINJIE will help us to find it.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# $(get_asset emu-precompile/emu-alu-err) \
#     -i $(get_asset workload/hello-riscv64-xs.bin ${AM_HOME}/apps/hello/build/hello-riscv64-xs.bin) \
#     --no-diff \
#     -C 20000 \
#     2>/dev/null || true

# %% [markdown]
# ## NEMU: ISA Reference

# %% [markdown]
# To know what is wrong, we need a reference for what is right. NEMU is that ISA-level reference model. It runs much faster than RTL and provides the expected architectural state. We will first run NEMU by itself, then compare it with RTL via DiffTest.
#
# ----- Speaker notes divider -----

# %% [markdown]
# "How does the simulation program know it has already encountered an error?"
#
# -> A reference model
#
# NEMU: a Spike-like ISA simulator
#
# - QEMU-like performance;
# - Exposes APIs to compare and verify XiangShan's architectural state.

# %% [markdown]
# NEMU provides two default configurations:
# - xxx_defconfig：xxx Default settings for standalone run mode
# - xxx-ref_defconfig：xxx As the default configuration for DiffTest co-simulation mode

# %% [markdown]
# NEMU has two relevant build modes. The standalone mode can make it run itself. And the reference mode will build it as a shared-library used by DiffTest. (RUN) Run the build cell here so you can see the standalone NEMU path before the co-simulation path.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NEMU_HOME}
#
# make clean
#
# # compile default config as standalone mode
# make riscv64-xs_defconfig | outputBuffer
# make -j | outputBuffer
#
# make clean-softfloat | outputBuffer
#
# # compile default config as reference mode
# make riscv64-xs-ref_defconfig | outputBuffer
# make -j | outputBuffer

# %% [markdown]
# Next, we run Hello XiangShan on NEMU in standalone mode.

# %% [markdown]
# Now we use standalone NEMU to run the same Hello workload. (RUN) It gives us a good reference for later comparisons.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NEMU_HOME}
#
# # Use the -b option to start NEMU in batch mode and avoid manually entering commands to run the workload.
# ./build/riscv64-nemu-interpreter \
#     -b \
#     $(get_asset workload/hello-riscv64-xs.bin) | outputBuffer

# %% [markdown]
# ## Difftest: ISA Co-simulation framework
#
# - How does the simulation program know it has already encountered an error
# - How to locate where the error occurred
#
# -> Co-sim RTL (DUT) and reference model (REF)
#
# <img src="../images/02-functional/02-difftest/difftest-arch-en.png" width="80%"/>

# %% [markdown]
# Now we have a good reference, then how to locate where the error occured? We propose DiffTest, an ISA Co-simulation framewor. After each committed instructions, it compares architectural state between Processor and reference.
# If there are differences, it will stop running and report the error. Otherwise it continues to run till the end.
# Then we can find out what is the first buggy state.
#
# ----- Speaker notes divider -----

# %% [markdown]
# When running emu, enable the DiffTest feature by specifying the path to the reference model's dynamic link library with the `--diff <path/to/ref.so>` parameter.
#
# We rerun the faulty emu with diff enabled:

# %% [markdown]
# Let's rerun the faulty ALU emulator, but this time with DiffTest enabled. (RUN) The key output is the first mismatch, especially the PC and the register value that differs between DUT and REF.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# $(get_asset emu-precompile/emu-alu-err) \
#     -i $(get_asset workload/hello-riscv64-xs.bin) \
#     --diff $(get_asset emu-precompile/riscv64-nemu-interpreter-so) \
#     2>/dev/null | tee emu_err.log > /dev/null || true # tutorial：add "|| true" to avoid notebook errors; It's not needed in real usage.
#
# tail -n 7 emu_err.log

# %% [markdown]
# At PC 0x0080000078, the REF and DUT are not matched: a0 is 0x2000 in the REF, but 0 in the DUT.

# %% [markdown]
# Difftest also prints useful information when an error is encountered, such as the values of architectural registers (integer/floating-point/vector/CSR).

# %% [markdown]
# The next log slice architectural registers at the mismatch. (RUN) When we read the output, look for the register whose REF value and DUT value differ. That difference is our first view about the buggy state.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# tail -n 95 emu_err.log | head -n 19 | outputBuffer

# %% [markdown]
# And the order of instruction commits and other information.

# %% [markdown]
# A register mismatch is more useful when we know the recent instruction history. (RUN) Run the next log command to see commit-order information. This short trace tells us what committed just before the mismatch, which helps us choose where to inspect the waveform.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# tail -n 124 emu_err.log | head -n 11 | outputBuffer

# %% [markdown]
# After Difftest detects an error, we can rerun the simulation and enable waveform output around the failing cycle reported by Difftest.

# %% [markdown]
# Once DiffTest tells us the failing cycle, we can rerun with waveform dumping around that point. (RUN) The important workflow is: first locate the mismatch with DiffTest, then dump a small waveform window, instead of dumping everything from cycle zero.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# mkdir -p build
# rm -f ./build/*.vcd
#
# $(get_asset emu-precompile/emu-alu-err) \
#     -i $(get_asset workload/hello-riscv64-xs.bin) \
#     --diff $(get_asset emu-precompile/riscv64-nemu-interpreter-so) \
#     -b 8000 \
#     -e 10000 \
#     --dump-wave \
#     2>/dev/null >/dev/null || true
#
# echo -n "Dump wave: "
# realpath ./build/*.vcd

# %% [markdown]
# ## LightSSS: Light-weight Simulation Snapshot System
#
# - How to locate where the error occurred -> Difftest
# - How to efficiently obtain waveform?
#   - Enable waveform at the first place -> Disk 💥
#   - Manually re-run -> Not efficient

# %% [markdown]
# So how to dump a small waveform exactly new the buggy state? If we enable waveform from the beginning, disk usage can grow very quickly. If we manually rerun many times, debugging becomes slow. That's talk about LightSSS, a light-weight simulation snapshot system.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ![LightSSS](../images/02-functional/03-lightSSS/lightSSS-overall-en.png)

# %% [markdown]
# The picture shows the LightSSS idea. The simulator periodically forks snapshot processes, and Linux copy-on-write keeps the cost low. When a failure is detected, an older snapshot can replay the latest window nearly the buggy state and dump the waveforms we actually need.
#
# ----- Speaker notes divider -----

# %% [markdown]
# To use LightSSS is straightforward. Simply add the `--enable-fork` parameter when running emu to enable the feature:

# %% [markdown]
# Using LightSSS is simple. Add --enable-fork when running emu. (RUN) Run this cell and look for the message saying the oldest checkpoint starts to dump wave and NEMU log. That message means the snapshot-based replay path is active.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# mkdir -p build
# rm -f ./build/*.vcd
#
# $(get_asset emu-precompile/emu-alu-err) \
#     -i $(get_asset workload/hello-riscv64-xs.bin) \
#     --diff $(get_asset emu-precompile/riscv64-nemu-interpreter-so) \
#     --enable-fork \
#     2> /dev/null | outputBuffer || true
#
# echo -n "Dump wave: "
# realpath ./build/*.vcd

# %% [markdown]
# If you see "the oldest checkpoint start to dump wave and dump nemu log...", LightSSS is active. The simulation will then restart from the latest snapshot and record waveforms.

# %% [markdown]
# ## ChiselDB：Debug-friendly structured database
#
# <img src="../images/02-functional/04-chiseldb/chiseldb-en.png" alt="chiselDB-overview" style="float:right; width:40%; margin-left:5px;">
#
# Waveforms are not the best choice for certain signals (e.g., bus transactions):
# - Storage waste
# - Not structured
#
# -> ChiselDB

# %% [markdown]
# Waveforms are great for timing, but not always great for structured events. For bus transactions, the ChiselDB view is often easier. It records selected hardware events into a SQLite database, so we can query by address, channel, opcode, or timestamp instead of hunting through raw signals.
#
# ----- Speaker notes divider -----

# %% [markdown]
# We provide a prebuilt simulator `emu-cdb-err` with an injected bug that forces all data released from L2 Cache to L3 Cache to a constant value.
#
# Enable ChiselDB with `--dump-db` and turn on DiffTest; after running, DiffTest reports an error and a `.db` file is generated under `./build`.

# %% [markdown]
# Here the injected cache bug forces data released from L2 to L3 to a constant value. (RUN) Run the cell with --dump-db and DiffTest enabled. DiffTest reports the mismatch, and ChiselDB writes a .db file under build for deeper transaction analysis.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# rm -f ./build/*.db # clean old files
# mkdir -p build
#
# $(get_asset emu-precompile/emu-cdb-err) \
#     -i $(get_asset workload/stream_100000.bin) \
#     --diff $(get_asset emu-precompile/riscv64-nemu-interpreter-so) \
#     --dump-db \
#     2>linux.err || true
#
# echo -n "Dump DB: "
# realpath ./build/*.db

# %% [markdown]
# Then use SQLite to read the `.db` for analysis: query all TileLink transactions at address `0x80048f00`, and format the output with `./scripts/cache/convert_tllog.sh`.

# %% [markdown]
# Now we query the database by address. (RUN) Run the SQLite command for the error address 0x80048f00. The formatter converts raw TLLog rows into a readable TileLink transaction trace. This is the database version of following one signal through time.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
#
# DB=$(ls -t ${NOOP_HOME}/build/*db | head -n 1)
#
# sqlite3 ${DB} "select * from TLLog where ADDRESS=0x80048f00" | sh ${NOOP_HOME}/scripts/cache/convert_tllog.sh | outputBuffer

# %% [markdown]
# Columns: timestamp to_from channel opcode permission address data
#
# Here we can see that:
#
# 1. L1D writes data back to L2
# ```
# 16171 L2_L1D_0 C ProbeAckData Shrink TtoN 0 5 80048f00 0000000080048f50 0000000080014328 0000000000000000 0000000000000000 user: 0 echo: 0
# 16172 L2_L1D_0 C ProbeAckData Shrink TtoN 0 5 80048f00 0000000000000000 0000000000000000 000000008001e000 0000000080042060 user: 0 echo: 0
# ```

# %% [markdown]
# The columns are timestamp, endpoints, channel, opcode, permission, address, and data. Start with item 1: L1D writes data back to L2 at 0x80048f00. The following fragments continue the same address through L3 and back to L1D, so we can see where the data becomes wrong.
#
# ----- Speaker notes divider -----

# %% [markdown]
# 2. And to L3
# ```
# 16179 L3_L2_0 C ProbeAckData Shrink TtoN 0 2 80048f00 0000000080048f50 0000000080014328 0000000000000000 0000000000000000 user: 0 echo: 1
# 16180 L3_L2_0 C ProbeAckData Shrink TtoN 0 2 80048f00 0000000000000000 0000000000000000 000000008001e000 0000000080042060 user: 0 echo: 1
# ```

# %% [markdown]
# 3. The next time L1D requests the data, L3->L2 GrantData does not match the original data written by L1D, indicating the bug.
# ```
# 16457 L2_L1D_0 A AcquireBlock Grow NtoT 0 0 80048f00 0000000000000000 0000000000000000 0000000000000000 0000000000000000 user: 80048f07 echo: 0
# 16463 L3_L2_0 A AcquireBlock Grow NtoT 0 0 80048f00 0000000000000000 0000000000000000 0000000000000000 0000000000000000 user: 0 echo: 1
# 16486 L3_L2_0 D GrantData Cap toT 1 0 80048f00 0000000000abcdef 0000000000000000 0000000000000000 0000000000000000 user: 0 echo: 1
# ```

# %% [markdown]
# ![TL-TEST](../images/02-functional/05-tl_test/tl-test-overall-en.png)

# %% [markdown]
# TL-Test is a cache-system level test environment. Instead of running the full XiangShan core and then looking backward from a system-level failure, TL-Test directly generates randomized TileLink traffic around the cache subsystem. This makes it a good tool for stress-testing coherence behavior and data movement between L1D, L2, and the surrounding TileLink interfaces.
#
# ----- Speaker notes divider -----

# %% [markdown]
# Here is another example to detect cache coherence violation by TL-Test. We inject a bug that wrongly shift the grant data.
#
# TL-Test generates randomized tests and pinpoints a transfer problem at a specific address in our cache design. It logs all bus transactions; we then use grep to extract log for analysis.

# %% [markdown]
# In this experiment, we intentionally inject a bug that shifts the data in a GrantData response. So the protocol may still produce a response, but the data returned to L1D is wrong. The job of TL-Test is to create randomized transactions, detect the mismatch, and report a compact failure context that we can inspect.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
#
# cat $(get_asset tltest-precompile/tlt_err.patch) | outputBuffer

# %%
# %%bash
# source ../env.sh
# # cd $TLT_HOME && make coupledL2-test-l2l3-v3 run THREADS_BUILD=16 CXX_COMPILER=clang++-17
# # cd $TLT_HOME/run && ./tltest_v3lt 2>&1 | tee tltest_v3lt.log
#
# get_asset tltest-precompile/tltest_err
# mkdir -p ${WORK_DIR}/02-functional/05-tltest
# cd ${WORK_DIR}/02-functional/05-tltest
#
# cp -r $(get_asset tltest-precompile) ./ && cd ./tltest-precompile
# ./tltest_err 2>&1 | tee tltest_v3lt.log > /dev/null
#
# tail -n 50 tltest_v3lt.log | head -n 15

# %% [markdown]
# This cell runs the prebuilt TL-Test case. The commented commands show how to build and run it from scratch, but for the tutorial we use the precompiled binary to save time. (RUN) After running it, do not try to read the whole log. We only need the failure summary first, because that summary tells us which address to follow.
#
# ----- Speaker notes divider -----

# %% [markdown]
# Error Addr： 0x80

# %% [markdown]
# The address 0x80 is not something we chose in advance. It comes from the TL-Test failure report. Once TL-Test detects that returned data does not match the expected data, it prints the related error address. We then use 0x80 as a clue: filter the log by this address and reconstruct what happened to that cache line.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# # grep "addr: 0x80" $TLT_HOME/run/tltest_v3lt.log
#
# cd ${WORK_DIR}/02-functional/05-tltest/tltest-precompile && grep "addr: 0x80," tltest_v3lt.log | head -n 10

# %% [markdown]
# Columns: [time] [INFO-level] #nodeIdx core [channel] [opcode] source, address, alias, data
#
# 1. L1D acquires Eaddr
# ```
# [236] [tl-test-new-INFO] #0 L2[0].C[0] [fire A] [AcquirePerm NtoT] source: 0x3, addr: 0x80, alias: 0
# ```

# %% [markdown]
# Now we read the log as a short transaction story, not as isolated lines. For address 0x80, L1D first acquires the line. Later, L1D releases data back to L2. Then, when L1D requests the line again, the GrantData response carries shifted or corrupted data. That sequence explains why TL-Test reports a data mismatch.
#
# ----- Speaker notes divider -----

# %% [markdown]
# 2. L1D release Eaddr, and data successfully transferred from L1D to L2
# ```
# [806] [tl-test-new-INFO] #0 L2[0].C[0] [fire C] [ReleaseData TtoN] source: 0x3, addr: 0x80, alias: 0, data: [ c7 a5 ... ]
# [808] [tl-test-new-INFO] #0 L2[0].C[0] [fire C] [ReleaseData TtoN] source: 0x3, addr: 0x80, alias: 0, data: [ fe 14 ... ]
# ```

# %% [markdown]
# 3. Next time L1D acquires Eaddr, L2 returns wrong data
# ```
# [2036] [tl-test-new-INFO] #0 L2[0].C[0] [fire D] [GrantData toT] source: 0xf, addr: 0x80, alias: 0x1, data: [ 00 c7 ... ]
# [2038] [tl-test-new-INFO] #0 L2[0].C[0] [fire D] [GrantData toT] source: 0xf, addr: 0x80, alias: 0x1, data: [ 00 fe ... ]
# ```

# %% [markdown]
# ![MinJie Cycle](../images/03-performance/00-intro/overview-en.png)

# %% [markdown]
# We now leave functional correctness and move to performance. The MinJie performance loop has the same spirit: collect evidence, summarize it, and decide what to change. The tools in this section are checkpointing, XSPerf counters, Top-Down analysis, and Constantin.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ![intro](../images/03-performance/01-checkpoint/intro-en.png)

# %% [markdown]
# For performance evaluation, We usually use some benchmarks like SPECCPU to run simulation. But as we all know, running these benchmarks directly through RTL simulation takes way too long.
# Although FPGA evaluation is fast, it takes too long for compilation and iteration, especially for complex design.
# Some emulators like Palladium manage to achieve both fast simulation and cmopilation, but their high prices are clearly unaffordable for individual developers and most academic researchers.
# So how can we achieve a performance evaluation method balancing agility/əˈdʒɪləti/ and affordability?
#
# We introduced checkpoints—a benchmark slicing technique that improves the parallelism of simulation-based performance evaluation.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ![method](../images/03-performance/01-checkpoint/method-en.png)

# %% [markdown]
# Common checkpoint techniques include Uniform checkpoint and SimPoint checkpoint:
# Uniform Checkpoint divides a program into equal segments for parallel simulation with uniform sampling.
# SimPoint Checkpoint selects representative segments through cluster analysis and weighted sampling.
#
# The checkpoint weights tell us how much each sampled region represents in the full program, so as to reduce the total checkpoint size for faster performance evaluation.
#
# ----- Speaker notes divider -----

# %% [markdown]
# This section will use some paths and constants different from `../env.sh`. For convenience, we have created a `01-env.sh`. In this section, we will use this script to set environment variables. You can run the following cell to view these environment variables.

# %% [markdown]
# As the checkpoint section uses different workload-specific paths and constants from previous session. (RUN) Please run the cell and double-check the environments. These variables define what program we checkpoint, how frequently we sample it, which NEMU binary performs profiling, and where the generated results are stored.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../03-performance/01-env.sh
#
# env | grep WORKLOAD= # workload to be simulated / profiled / checkpointed
# env | grep CHECKPOINT_INTERVAL=
# env | grep NEMU=
# env | grep _HOME | tail
# env | grep _PATH | tail

# %% [markdown]
# The first step to perform checkpointing is to compile SimPoint tool and NEMU (in checkpoint mode), and generate a checkpoint restorer.

# %% [markdown]
# The first real step is building the checkpoint tools. SimPoint selects representative segments, NEMU profiles and generates checkpoints, and the checkpoint restorer helps emu start from the saved architectural state.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../03-performance/01-env.sh
#
# cd ${NEMU_HOME}
# git submodule update --init
#
# # Compile simpoint generator
# cd ${NEMU_HOME}/resource/simpoint/simpoint_repo
# make clean
# make
#
# # Compile NEMU in checkpoint mode
# cd ${NEMU_HOME}
# make clean
# make riscv64-xs-cpt_defconfig
# make -j8
#
# # Generate checkpoint restorer for ${WORKLOAD}
# cd ${NEMU_HOME}/resource/gcpt_restore
# rm -rf ${GCPT_PATH}
# make -C ${NEMU_HOME}/resource/gcpt_restore/ \
#     O=${GCPT_PATH} \
#     GCPT_PAYLOAD_PATH=$(get_asset workload/${WORKLOAD}.bin) \
#     CROSS_COMPILE=riscv64-linux-gnu-

# %% [markdown]
# Next, we need to run the program to be checkpointed using NEMU to collect program behavior for profiling.

# %% [markdown]
# Next NEMU collects profiling information from the workload. (RUN) Run the cell, or inspect the command if we are using pre-generated data. The output goes under RESULT_PATH and LOG_PATH, so later steps can find the profiling vectors.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../03-performance/01-env.sh
#
# rm -rf ${RESULT_PATH}
#
# _LOG_PATH=${LOG_PATH}/profiling
# mkdir -p ${_LOG_PATH}
#
# ${NEMU} ${GCPT} \
#     -w ${WORKLOAD} \
#     -D ${RESULT_PATH} \
#     -C profiling \
#     -b \
#     --simpoint-profile \
#     --cpt-interval ${CHECKPOINT_INTERVAL} \
#     > >(tee ${_LOG_PATH}/${WORKLOAD}-out.txt | outputBuffer) 2> >(tee ${_LOG_PATH}/${WORKLOAD}-err.txt)

# %% [markdown]
# Then, use SimPoint to perform clustering analysis on the collected program behavior, selecting segments.

# %% [markdown]
# Now SimPoint clusters the profiling data. (RUN) Run this cell to select representative segments. The random seeds in the command make the clustering process explicit. The output tells us which parts of the program should become checkpoints.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../03-performance/01-env.sh
#
# CLUSTER=${RESULT_PATH}/cluster/${WORKLOAD}
# mkdir -p ${CLUSTER}
#
# random1=`head -20 /dev/urandom | cksum | cut -c 1-6`
# random2=`head -20 /dev/urandom | cksum | cut -c 1-6`
#
# _LOG_PATH=${LOG_PATH}/cluster
# mkdir -p ${_LOG_PATH}
#
# ${SIMPOINT} \
#     -loadFVFile ${PROFILING_RESULT_PATH}/${WORKLOAD}/simpoint_bbv.gz \
#     -saveSimpoints ${CLUSTER}/simpoints0 \
#     -saveSimpointWeights ${CLUSTER}/weights0 \
#     -inputVectorsGzipped \
#     -maxK 3 \
#     -numInitSeeds 2 \
#     -iters 1000 \
#     -seedkm ${random1} \
#     -seedproj ${random2} \
#     > >(tee ${_LOG_PATH}/${WORKLOAD}-out.txt | outputBuffer) 2> >(tee ${_LOG_PATH}/${WORKLOAD}-err.txt)

# %% [markdown]
# Finally, use NEMU to rerun the program that needs to be checkpointed to generate checkpoint files.

# %% [markdown]
# After selecting the segments, NEMU reruns the workload and writes checkpoint files. (RUN) Run this cell to generate them. Each checkpoint captures memory and architectural state at a selected interval, so emu can resume from that point later.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../03-performance/01-env.sh
#
# CLUSTER=${RESULT_PATH}/cluster
# _LOG_PATH=${LOG_PATH}/checkpoint
# mkdir -p ${_LOG_PATH}
#
# ${NEMU} ${GCPT} \
#     -w ${WORKLOAD} \
#     -D ${RESULT_PATH} \
#     -C checkpoint \
#     -b \
#     -S ${CLUSTER} \
#     --cpt-interval ${CHECKPOINT_INTERVAL} \
#     > >(tee ${_LOG_PATH}/${WORKLOAD}-out.txt | outputBuffer) 2> >(tee ${_LOG_PATH}/${WORKLOAD}-err.txt)

# %% [markdown]
# Go to the directory `${RESULT_PATH}/checkpoint/${WORKLOAD}`, you can see the generated checkpoint files, a total of cluster number of `.gz` files, with the weight of the checkpoint indicated in the file name.

# %% [markdown]
# Let's inspect the generated checkpoint directory. (RUN) Run the find command and look for files ending in _.gz. These are compressed checkpoints. The filenames also carry weights, which matter when combining results.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../03-performance/01-env.sh
#
# find "${RESULT_PATH}/checkpoint/${WORKLOAD}" -type f -name "*_.gz" | tail

# %% [markdown]
# We can use emu to run one of the generated checkpoints and see the effect.

# %% [markdown]
# Now we use one checkpoint as the input to emu. (RUN) Run this cell. emu detects the gzip-compressed checkpoint and restores the saved state. This lets RTL simulation start near a representative workload region instead of from the beginning of the program.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../03-performance/01-env.sh
#
# CHECKPOINT=$(find ${RESULT_PATH}/checkpoint/${WORKLOAD} -type f -name "*_.gz" | tail -1)
#
# $(get_asset emu-precompile/emu) \
#     -i ${CHECKPOINT} \
#     --diff $(get_asset emu-precompile/riscv64-nemu-interpreter-so) \
#     --max-cycles=50000 \
#     2>/dev/null \
#     | outputBuffer

# %% [markdown]
# ## Performance counter in XiangShan
#
# Purpose: Collect performance events for analysis and tuning
#
# XSPerf:
# - Accumulate:
#   ```c
#   if (valid)
#     counter += diff;
#   ```
# - Histogram:
#   ```c
#   if (valid)
#     distribution[value / step] += 1;
#   ```
# - Rolling:
#   ```c
#   if (valid)
#     counters[segment] += diff;
#   if (cycles++ == segment_size) {
#     cycles = 0;
#     segment++;
#   }
#   ```

# %% [markdown]
# Once we can run meaningful regions, we need measurements. XSPerf provides three counter styles: Accumulate for totals, Histogram for distributions, and Rolling for time-series data. Think of them as answering how many, what distribution, and when during execution.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ### Accumulate & Histogram
#
# These two types of performance counters are printed to stderr when the simulation ends.
#
# Example (Accumulate): the total number of instructions committed
#
# ```scala
# def ifCommitReg(counter: UInt): UInt = Mux(isCommitReg, counter, 0.U)
# XSPerfAccumulate("commitInstr", ifCommitReg(trueCommitCnt), XSPerfLevel.CRITICAL)
# ```
#
# Example (Histogram): the distribution of L2 Cache acquire latency
#
# ```scala
# XSPerfHistogram("acquire_period", acquire_period, acquire_period_en, 0, 30, 1, true, true)
# XSPerfHistogram("acquire_period", acquire_period, acquire_period_en, 30, 100, 5, true, true)
# XSPerfHistogram("acquire_period", acquire_period, acquire_period_en, 100, 200, 10, true, true)
#
# ```

# %% [markdown]
# The examples here map the counter types to real RTL code. commitInstr is an accumulated total. acquire_period is a histogram of L2 acquire latency. (RUN) The next cell will run a short workload and grep stderr.log for both examples.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# $(get_asset emu-precompile/emu) \
#     -i $(get_asset workload/hello-riscv64-xs.bin) \
#     --no-diff 2>stderr.log | tail
#
# echo "=== Last 10 lines:"
# tail -n 10 stderr.log
#
# echo "=== Example of XSPerfAccumulate: rob commitInstr"
# grep -n "rob: commitInstr," stderr.log | tail
#
# echo "=== Example of XSHistogram: l2cache acquire period"
# grep -n "l2cache.slices_0.mshrCtl: acquire_period" stderr.log | tail

# %% [markdown]
# Please run this cell and read the labeled output blocks. (RUN) It first runs emu with --no-diff, then prints the last lines of stderr.log, then greps for rob commitInstr and l2cache acquire_period. This is the fastest way to inspect basic XSPerf output.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ### Rolling
#
# ![rolling](../images/03-performance/02-xsperf/rolling-en.png)
#
# This type of performance counter utilizes the ChiselDB framework introduced in 02-functional/04-chiseldb to store the collected data into a SQLite3 database file.
#
# To enable RollingDB, you need to specify `WITH_ROLLINGDB=1` during compilation and use the `--dump-db` parameter at runtime.

# %% [markdown]
# Rolling counters add time information. The diagram shows that values are stored segment by segment in a database. This is useful when the workload has phases, because an average IPC can hide a short but important stall region.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ⚠️Note: If you are reading this notebook on the tutorial demo server, please do not recompile XiangShan, as it will take a long time and consume a lot of computing resources.

# %% [markdown]
# This warning matters on the shared server. RollingDB requires WITH_ROLLINGDB=1 at compile time, and recompilation is expensive. (RUN) The next cell copies a pre-generated rolling database so everyone can continue without stressing the demo machine.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${NOOP_HOME}
#
# mkdir -p ${WORK_DIR}/03-performance/02-xsperf
#
# # for tutorial: copy a pre-generated rolling db to tutorial dir
# cp $(get_asset emu-perf-result/xs-perf-rolling.db) \
#     ${WORK_DIR}/03-performance/02-xsperf/xs-perf-rolling.db

# %% [markdown]
# After obtaining the database file, we use a python script to analyze it.
#
# In the following example, we use the rollingplot.py script to plot ipc data.
#
# Gathering ipc data in XiangShan's RTL code is as follows:
#
# ```scala
# // every 1000 cycles
# XSPerfRolling("ipc", ifCommitReg(trueCommitCnt), 1000, clock, reset)
# ```

# %% [markdown]
# Now we analyze the rolling database. (RUN) Run the Python plotting command. In the RTL snippet, XSPerfRolling records IPC every 1000 cycles. The script turns those database records into a performance plot we can inspect visually.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
# cd ${WORK_DIR}/03-performance/02-xsperf
#
# # Use python scripts to analyze the rolling db, for example, plot ipc
# python3 ${NOOP_HOME}/scripts/rolling/rollingplot.py \
#     ./xs-perf-rolling.db \
#     ipc
#
# ls -lh ${WORK_DIR}/03-performance/02-xsperf/results/perf.png

# %% [markdown]
# The script outputs the following image, showing the IPC changes of XiangShan over time while running this program:
#
# <img src="../images/03-performance/02-xsperf/result-example.png" alt="Result Example" width="70%" />
#
# (at ../work/03-performance/02-xsperf/results/perf.png)
#
# If the image does not load correctly, you can try closing the notebook and reopening it.

# %% [markdown]
# Here is the expected IPC plot. If the image loads, look for stable regions, drops, and recoveries. If it does not load, the path shown on the slide tells you where the generated perf.png should be.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ## Top-Down
#
# Purpose: Organize perf events in hierarchical form
#
# [1]: Yasin A. A top-down method for performance analysis and counters architecture\[C\]//2014 IEEE International Symposium on Performance Analysis of Systems and Software (ISPASS). IEEE, 2014: 35-44.
#
# <img src="../images/03-performance/03-topdown/example-en.png" alt="Example" width="70%" />

# %% [markdown]
# Top-Down analysis helps us organize many counters into a hierarchy. Instead of jumping between unrelated events, we start with a high-level category, such as frontend, backend, bad speculation, or retiring, then drill into the part that dominates.
#
# ----- Speaker notes divider -----

# %% [markdown]
# In the `${NOOP_HOME}/scripts/top-down` directory, we have also implemented some analysis scripts that you can run to extract Top-Down results, plot graphs, etc..
#
# ⚠️Note: If you are reading this notebook on the tutorial demo server, please do not run the analysis scripts as they will perform a large amount of disk access.

# %% [markdown]
# XiangShan provides Top-Down scripts under ${NOOP_HOME}/scripts/top-down. Because the analysis can do a lot of disk access, we use pre-generated results in the live demo. (RUN) Run the copy cell if needed.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
#
# mkdir -p ${WORK_DIR}/03-performance/03-topdown
# cd ${WORK_DIR}/03-performance/03-topdown
#
# # for tutorial: copy analysis results
# cp -r $(get_asset emu-spec-topdown-result/results) ./
#
# echo === results ===
# ls ./results
#
# echo === first 10 lines of results.csv ===
# head -n 10 ./results/results.csv
#
# echo === first 10 lines of results-weighted.csv ===
# head -n 10 ./results/results-weighted.csv

# %% [markdown]
# The script outputs the following image:
#
# <img src="../images/03-performance/03-topdown/result-example.png" alt="Result Example" width="70%" />
#
# (at ../work/03-performance/03-topdown/results/result.png)
#
# If the image does not load correctly, you can try closing the notebook and reopening it.

# %% [markdown]
# The result image should be read from coarse to fine. Start with the largest top-level bucket, then inspect its children. That keeps the performance discussion focused on the dominant bottleneck instead of whichever small counter happens to catch our eye.
#
# ----- Speaker notes divider -----

# %% [markdown]
# ## Constantin
#
# Purpose: Speed-up design space exploration (by reducing re-compilation)
#
# <img src="../images/03-performance/04-constantin/overview-en.png" alt="Overview" width="80%" />

# %% [markdown]
# The final tool is Constantin, which reduces recompilation during design-space exploration. The idea is to mark selected parameters as runtime-configurable. Then we can change a text file and rerun emu, instead of editing Scala and rebuilding RTL for every experiment.
#
# ----- Speaker notes divider -----

# %% [markdown]
# To replace a scala parameter with Constantin, it looks roughly like this:
#
# ```scala
# /* *** w/o Constantin *** */
# val enableSomeModule = WireInit(false.B) // change to true.B, re-compile and re-run
#
# /* *** w/ Constantin *** */
# // in RTL
# val enableSomeModule = WireInit(Constantin.createRecord("enableSomeModule", initValue = false))
# // in constantin.txt
# enableSomeModule 0 // change to 1, re-run
# ```
#
# To enable Constantin, you need to use the `WITH_CONSTANTIN=1` option when compiling emu.
#
# Currently, Constantin does not present as an emu argument, its configuration file must be located at `${NOOP_HOME}/build/constantin.txt`.

# %% [markdown]
# The code comparison shows the tradeoff. Without Constantin, changing false.B to true.B requires a rebuild. With Constantin, the RTL reads a record and constantin.txt supplies the value. The emulator must be built with WITH_CONSTANTIN=1.
#
# ----- Speaker notes divider -----

# %% [markdown]
# The following example uses Constantin to control the switch of the branch predictor. You can run this cell to compare the differences between on and off.

# %% [markdown]
# This example toggles a branch predictor setting through Constantin. (RUN) Run the cell and compare the two runs. The important part is not the exact number, but the experiment loop: same compiled emulator, edit runtime parameter, rerun, compare.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
#
# mkdir -p ${NOOP_HOME}/build
#
# # run with default parameter
# rm -f ${NOOP_HOME}/build/constantin.txt || true
# $(get_asset emu-precompile/emu-constantin) \
#     -i $(get_asset workload/coremark-2-iteration.bin) \
#     -C 10000 \
#     --no-diff \
#     2>/dev/null \
#     | tail
#
# # run with Bpu turned off (falls back to static not-taken prediction)
# echo "constCtrl 1" > ${NOOP_HOME}/build/constantin.txt
# $(get_asset emu-precompile/emu-constantin) \
#     -i $(get_asset workload/coremark-2-iteration.bin) \
#     -C 10000 \
#     --no-diff \
#     2>/dev/null \
#     | tail

# %% [markdown]
# ### Autosolving
# Purpose: automatically find the best parameter configuration under the current microarchitecture.
#
# Steps:
# - Enable in Constantin configuration (refer to `./04-autosolving.patch`);
# - Compile emu with `WITH_CONSTANTIN=1`;
# - Provide config file.
#   - Parameter name, bit width, initial value.
#   - Performance counter name, optimization strategy.
#   - Workload, etc..

# %% [markdown]
# Autosolving automates that experiment loop. The configuration tells the tool which parameters can change, how wide they are, which performance counter to optimize, and which workload to use. That turns manual parameter tuning into a scripted search.
#
# ----- Speaker notes divider -----

# %%
# %%bash
# source ../env.sh
#
# echo === Patch ===
# cat ./04-autosolving.patch
#
# echo === Config ===
# cat ./04-autosolving-config.json
#
# echo === Run ===
# mkdir -p ${NOOP_HOME}/build
# cp $(get_asset emu-precompile/emu-autosolving) ${NOOP_HOME}/build/emu
# python3 ${NOOP_HOME}/scripts/constantHelper.py ./04-autosolving-config.json

# %% [markdown]
# The final cell prints the patch, the JSON config, and the run command. (RUN) Execute it as the closing demo. Read it as a template: the patch exposes tunable knobs, the JSON file describes the search, and constantHelper.py drives the runs.
#
# ----- Speaker notes divider -----

# %% [markdown]
# <img src="../images/summary.png" alt="Summary" width="100%" />

# %% [markdown]
# By now, you are ready to get hands-on with the functional and performance verification processes for XiangShan.
# Let’s review our MinJie development flows and tools.
# When introducing a new feature, we follow a structured development process that includes RTL implementation, functional and performance verification before physical design. We’ve established a comprehensive toolchain below the water surface throughout this process. (不翻页)
# Thank you for listening! If you have any questions, please feel free to contact us.
#
# ----- Speaker notes divider -----
